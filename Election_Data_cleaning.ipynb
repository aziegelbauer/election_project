# %%
#imports libraries and csv file
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv(('P00000001-ALL 2.csv'), index_col=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (6,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (7440252, 18)

# %%
array = ['Clinton, Hillary Rodham', 'Sanders, Bernard', 'Trump, Donald J.']
df = df.loc[df['cand_nm'].isin(array)]

# %%
#changes names of candidates to be more intuitive
#df['cand_nm'] = df['cand_nm'].replace(['Rubio, Marco'], 'Marco Rubio')
#df['cand_nm'] = df['cand_nm'].replace(['Santorum, Richard J.'], 'Rick Santorum')
#df['cand_nm'] = df['cand_nm'].replace(['Perry, James R. (Rick)'], 'Rick Perry')
#df['cand_nm'] = df['cand_nm'].replace(['Carson, Benjamin S.'], 'Ben Carson')
#df['cand_nm'] = df['cand_nm'].replace(["Cruz, Rafael Edward 'Ted'"], 'Ted Cruz')
#df['cand_nm'] = df['cand_nm'].replace(['Paul, Rand'], 'Rand Paul')
df['cand_nm'] = df['cand_nm'].replace(['Clinton, Hillary Rodham'], 'Hillary Clinton')
df['cand_nm'] = df['cand_nm'].replace(['Sanders, Bernard'], 'Bernie Sanders')
#df['cand_nm'] = df['cand_nm'].replace(['Fiorina, Carly'], 'Fiorina Carly')
#df['cand_nm'] = df['cand_nm'].replace(['Huckabee, Mike'], 'Mike Huckabee')
#df['cand_nm'] = df['cand_nm'].replace(['Pataki, George E.'], 'George Pataki')
#df['cand_nm'] = df['cand_nm'].replace(["O'Malley, Martin Joseph"], "Martin O'Malley")
#df['cand_nm'] = df['cand_nm'].replace(['Graham, Lindsey O.'], 'Lindsey Graham')
#df['cand_nm'] = df['cand_nm'].replace(['Bush, Jeb'], 'Jeb Bush')
df['cand_nm'] = df['cand_nm'].replace(['Trump, Donald J.'], 'Donald Trump')
#df['cand_nm'] = df['cand_nm'].replace(['Jindal, Bobby'], 'Bobby Jindal')
#df['cand_nm'] = df['cand_nm'].replace(['Christie, Christopher J.'], 'Chris Christie')
#df['cand_nm'] = df['cand_nm'].replace(['Walker, Scott'], 'Scott Walker')
#df['cand_nm'] = df['cand_nm'].replace(['Stein, Jill'], 'Jill Stein')
#df['cand_nm'] = df['cand_nm'].replace(['Webb, James Henry Jr.'], 'Jim Webb')
#df['cand_nm'] = df['cand_nm'].replace(['Kasich, John R.'], 'John Kasich')
#df['cand_nm'] = df['cand_nm'].replace(['Gilmore, James S III'], 'Jim Gilmore')
#df['cand_nm'] = df['cand_nm'].replace(['Lessig, Lawrence'], 'Lawrence Lessig')
#df['cand_nm'] = df['cand_nm'].replace(['Johnson, Gary'], 'Gary Johnson')
#df['cand_nm'] = df['cand_nm'].replace(['McMullin, Evan'], 'Evan McMullin')

# %%
df.head(5)
# Out:
#           cmte_id    cand_id          cand_nm         contbr_nm contbr_city  \
# 944018  C00575795  P00003392  Hillary Clinton       DYSON, LISA         DPO
# 944019  C00575795  P00003392  Hillary Clinton   LARSEN, CARLENE         DPO
# 944020  C00575795  P00003392  Hillary Clinton  TREICHEL, SHANNA         DPO
# 944021  C00575795  P00003392  Hillary Clinton    ROBINSON, TODD         DPO
# 944022  C00575795  P00003392  Hillary Clinton       DYSON, LISA         DPO
#
#        contbr_st contbr_zip             contbr_employer  \
# 944018        AA  340040305  U.S. DEPARTMENT OF DEFENSE
# 944019        AA  340049997    U.S. DEPARTMENT OF STATE
# 944020        AA  340049997               SELF-EMPLOYED
# 944021        AA  340240001    U.S. DEPARTMENT OF STATE
# 944022        AA  340040305  U.S. DEPARTMENT OF DEFENSE
#
#                   contbr_occupation  contb_receipt_amt contb_receipt_dt  \
# 944018                STAFF OFFICER             152.24        24-FEB-16
# 944019            LOGISTICS ADVISOR              15.00        06-APR-16
# 944020  PUBLIC RELATIONS CONSULTANT             100.00        26-JUL-16
# 944021                     DIPLOMAT             250.00        29-JUL-16
# 944022                STAFF OFFICER              50.00        12-FEB-16
#
#        receipt_desc memo_cd               memo_text form_tp  file_num  \
# 944018          NaN       X  * HILLARY VICTORY FUND    SA18   1093618
# 944019          NaN     NaN                     NaN   SA17A   1091718
# 944020          NaN     NaN                     NaN   SA17A   1109498
# 944021          NaN     NaN                     NaN   SA17A   1109498
# 944022          NaN     NaN                     NaN   SA17A   1093618
#
#          tran_id election_tp
# 944018  C3113559       P2016
# 944019  C4036418       P2016
# 944020  C7613224       P2016
# 944021  C7909621       G2016
# 944022  C2603151       P2016

# %%
df.shape
# Out:
# (6351889, 18)

# %%
df.to_csv('clean_election_data.csv')

# %% [markdown]
# ### Data Specs
# #### 25 different candidated
# #### 1,393,128 individual contributors
# #### 399,178 contributor employers
# #### 127,670 contributor occupations
# #### 26,454 cities
# #### 116 "states"
# #### 941,017 contributions made in years previous to 2016
# #### 6,499,235 contributions made in 2016

# %%
import numpy as np
df = pd.read_csv(('clean_election_data.csv'), index_col=None)
np.random.seed(30)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-bf8782988214> in <module>()
#       1 import numpy as np
# ----> 2 df = pd.read_csv(('clean_election_data.csv'), index_col=None)
#       3 np.random.seed(30)
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1837     def read(self, nrows=None):
#    1838         try:
# -> 1839             data = self._reader.read(nrows)
#    1840         except StopIteration:
#    1841             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_integer_dtype(arr_or_dtype)
#     775
#     776
# --> 777 def is_integer_dtype(arr_or_dtype):
#     778     """
#     779     Check whether the provided array or dtype is of an integer dtype.
#
# KeyboardInterrupt:

# %%
df.shape

# %%
df = df.dropna()

# %%
df.shape

# %%
samp = df.sample(200000)

# %%
#drops columns with unnecessary data
samp.drop(['cmte_id', 'cand_id', 'contbr_zip', 'receipt_desc', 'memo_cd', 'memo_text', 'form_tp', 'file_num', 'tran_id', 'election_tp'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-7d5f361e8a0a> in <module>()
#       1 #drops columns with unnecessary data
# ----> 2 df.drop(['cmte_id', 'cand_id', 'contbr_zip', 'receipt_desc', 'memo_cd', 'memo_text', 'form_tp', 'file_num', 'tran_id', 'election_tp'], axis=1, inplace=True)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['cmte_id' 'cand_id' 'contbr_zip' 'receipt_desc' 'memo_cd' 'memo_text'
#  'form_tp' 'file_num' 'tran_id' 'election_tp'] not contained in axis

# %%
#converts date column to datetime
samp['contb_receipt_dt'] = pd.to_datetime(samp['contb_receipt_dt'])
#creates new columns for day, month, and year    
samp['month'] = samp['contb_receipt_dt'].dt.month
samp['day'] = samp['contb_receipt_dt'].dt.day
samp['year'] = samp['contb_receipt_dt'].dt.year

# %%
#changes some column names
samp = samp.rename(columns={'contb_receipt_amt': 'contribution_amt','contb_receipt_dt': 'contribution_date' })

# %%
samp.shape
# Out:
# (200000, 12)

# %%
samp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 4494866 to 2248685
# Data columns (total 12 columns):
# Unnamed: 0           200000 non-null int64
# cand_nm              200000 non-null object
# contbr_nm            200000 non-null object
# contbr_city          200000 non-null object
# contbr_st            200000 non-null object
# contbr_employer      200000 non-null object
# contbr_occupation    200000 non-null object
# contribution_amt     200000 non-null float64
# contribution_date    200000 non-null datetime64[ns]
# month                200000 non-null int64
# day                  200000 non-null int64
# year                 200000 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 19.8+ MB

# %%
samp.to_csv('election.csv')

# %%
df = pd.read_csv('election.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          cand_nm              contbr_nm  \
# 0     4494866       5438884   Bernie Sanders          MICHIE, JAMES
# 1     4405521       5349539   Bernie Sanders           PEIRCE, ERIC
# 2     6140449       7159957     Donald Trump  HARGETT, JOYCE E MRS.
# 3     3998515       4942533   Bernie Sanders           HICKS, MITZI
# 4      675318       1619336  Hillary Clinton          WALSHE, SUSAN
#
#   contbr_city contbr_st               contbr_employer  \
# 0    BETHESDA        MD                  NOT EMPLOYED
# 1    AMESBURY        MA  CATS N JAMMERS MUSIC STUDIOS
# 2  HARRISBURG        OR                       RETIRED
# 3      GOLDEN        CO           THE CONFLICT CENTER
# 4  LONG BEACH        CA       SUSAN WALSHE, LMFT, INC
#
#            contbr_occupation  contb_receipt_amt contb_receipt_dt  month  day  \
# 0               NOT EMPLOYED             100.00       2016-02-28      2   28
# 1                    TEACHER              27.00       2016-04-05      4    5
# 2                    RETIRED              40.00       2016-07-01      7    1
# 3    NONPROFIT ADMINISTRATOR               5.00       2016-04-25      4   25
# 4  MARRIAGE FAMILY THERAPIST              20.72       2016-10-07     10    7
#
#    year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#            cand_nm              contbr_nm contbr_city contbr_st  \
# 0   Bernie Sanders          MICHIE, JAMES    BETHESDA        MD
# 1   Bernie Sanders           PEIRCE, ERIC    AMESBURY        MA
# 2     Donald Trump  HARGETT, JOYCE E MRS.  HARRISBURG        OR
# 3   Bernie Sanders           HICKS, MITZI      GOLDEN        CO
# 4  Hillary Clinton          WALSHE, SUSAN  LONG BEACH        CA
#
#                 contbr_employer          contbr_occupation  contb_receipt_amt  \
# 0                  NOT EMPLOYED               NOT EMPLOYED             100.00
# 1  CATS N JAMMERS MUSIC STUDIOS                    TEACHER              27.00
# 2                       RETIRED                    RETIRED              40.00
# 3           THE CONFLICT CENTER    NONPROFIT ADMINISTRATOR               5.00
# 4       SUSAN WALSHE, LMFT, INC  MARRIAGE FAMILY THERAPIST              20.72
#
#   contb_receipt_dt  month  day  year
# 0       2016-02-28      2   28  2016
# 1       2016-04-05      4    5  2016
# 2       2016-07-01      7    1  2016
# 3       2016-04-25      4   25  2016
# 4       2016-10-07     10    7  2016

# %%
df.to_csv('election_final.csv')

# %%
df = pd.read_csv(('Expenditure_.csv'), index_col=False)
#contr = pd.read_csv('election_final.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#drops columns with unnecessary data
df.drop(['cmte_id', 'cand_id', 'recipient_zip', 'memo_cd', 'form_tp', 'file_num', 'tran_id', 'election_tp'], axis=1, inplace=True)

# %%
#converts date column to datetime
df['disb_dt'] = pd.to_datetime(df['disb_dt'])
#creates new columns for day, month, and year    
df['month'] = df['disb_dt'].dt.month
df['day'] = df['disb_dt'].dt.day
df['year'] = df['disb_dt'].dt.year

# %%
array = ['Clinton, Hillary Rodham', 'Sanders, Bernard', 'Trump, Donald J.']
df = df.loc[df['cand_nm'].isin(array)]

# %%
#changes names of candidates to be more intuitive
#df['cand_nm'] = df['cand_nm'].replace(['Rubio, Marco'], 'Marco Rubio')
#df['cand_nm'] = df['cand_nm'].replace(['Carson, Benjamin S.'], 'Ben Carson')
#df['cand_nm'] = df['cand_nm'].replace(["Cruz, Rafael Edward 'Ted'"], 'Ted Cruz')
#df['cand_nm'] = df['cand_nm'].replace(['Paul, Rand'], 'Rand Paul')
df['cand_nm'] = df['cand_nm'].replace(['Clinton, Hillary Rodham'], 'Hillary Clinton')
df['cand_nm'] = df['cand_nm'].replace(['Sanders, Bernard'], 'Bernie Sanders')
#df['cand_nm'] = df['cand_nm'].replace(['Fiorina, Carly'], 'Fiorina Carly')
#df['cand_nm'] = df['cand_nm'].replace(['Huckabee, Mike'], 'Mike Huckabee')
#df['cand_nm'] = df['cand_nm'].replace(['Bush, Jeb'], 'Jeb Bush')
df['cand_nm'] = df['cand_nm'].replace(['Trump, Donald J.'], 'Donald Trump')
#df['cand_nm'] = df['cand_nm'].replace(['Christie, Christopher J.'], 'Chris Christie')
#df['cand_nm'] = df['cand_nm'].replace(['Walker, Scott'], 'Scott Walker')
#df['cand_nm'] = df['cand_nm'].replace(['Stein, Jill'], 'Jill Stein')
#df['cand_nm'] = df['cand_nm'].replace(['Kasich, John R.'], 'John Kasich')
#df['cand_nm'] = df['cand_nm'].replace(['Johnson, Gary'], 'Gary Johnson')

# %%
#df['transaction_type'] = 'Expenditure'
#contr['transaction_type'] = 'Contribution'

# %%
df.shape
# Out:
# (192556, 11)

# %%
df = df.rename(columns={'disb_amt': 'expenditure_amt','disb_desc': 'expenditure_type', 'disb_dt': 'expenditure_date', 'memo_text': 'expenditure_memo'})

# %%
df.head()
# Out:
#                cand_nm        recipient_nm  expenditure_amt expenditure_date  \
# 42430  Hillary Clinton  MARSCH ENTERPRISES          1500.00       2016-03-31
# 42431  Hillary Clinton  GROH, KEVIN DANIEL          1242.73       2016-03-30
# 42432  Hillary Clinton       TICE, CHARLES            30.00       2016-05-13
# 42433  Hillary Clinton  GROH, KEVIN DANIEL          1345.63       2016-03-15
# 42434  Hillary Clinton  MARSCH ENTERPRISES          1500.00       2016-03-31
#
#       recipient_city recipient_st expenditure_type expenditure_memo  month  \
# 42430      ANCHORAGE           AK             RENT              NaN      3
# 42431          SITKA           AK          PAYROLL              NaN      3
# 42432      ANCHORAGE           AK            PHONE              NaN      5
# 42433          SITKA           AK          PAYROLL              NaN      3
# 42434      ANCHORAGE           AK             RENT              NaN      3
#
#        day  year
# 42430   31  2016
# 42431   30  2016
# 42432   13  2016
# 42433   15  2016
# 42434   31  2016

# %%
df.dropna(subset = ['expenditure_type'], inplace=True)

# %%
df.shape
# Out:
# (192541, 11)

# %%
df['expenditure_type'].value_counts()
# Out:
# Travel                                      85599
# Payroll                                     38555
# Phone                                       19755
# Misc Fees                                    5823
# Various Rentals                              4273
# Office Supplies                              3953
# Event Supplies                               3496
# Shipping                                     3360
# Various Consulting                           3237
# Catering                                     3014
# PRINTING                                     1570
# UTILITIES                                    1233
# COMPUTER EQUIPMENT                           1104
# VENUE                                        1002
# LODGING                                       981
# EVENT PRODUCTION                              917
# CATERING                                      828
# SOFTWARE                                      654
# MEDIA PRODUCTION                              523
# AUDIO VISUAL SERVICES                         512
# SUBSCRIPTION                                  475
# TECHNOLOGY SERVICES                           458
# PER DIEM                                      377
# PARKING                                       367
# EVENT PLANNING SERVICES                       341
# POLLING                                       334
# INTERPRETING SERVICES                         320
# ORGANIZING SERVICES                           311
# SECURITY SERVICES                             304
# PHOTOGRAPHY/VIDEO EQUIPMENT                   302
#                                             ...
# MEETING EXPENSE: MEALS [NAGEL: SB23.6629        1
# CREDIT CARD PAYMENTS: MEMO AGGREGATES UN        1
# EVENT EXPENSE: STAGING                          1
# FUEL COSTS, LODGING; FEDERALLY PERMISSIB        1
# VENUE; FEDERALLY PERMISSIBLE FUNDS              1
# GRASSROOTS TRAINING SERVICES                    1
# SIGN LANGUAGE INTERPRETER SERVICES              1
# TRANSPORTATION SERVICES [AMEX: SB23.1808        1
# VOTER ACTIVATION NETWORK                        1
# EVENT INSURANCE                                 1
# SECURITY SERVICES [AMEX SB23.2859923]           1
# SECURITY/FIRE/EMS SERVICES                      1
# SECURITY SERVICES/JANITORIAL                    1
# EVENT EXPENSE: PARKING SERVICES                 1
# EQUIPMENT PURCHASE [AMEX: SB23.2859906]         1
# UTILITIES [AMEX: SB23.288951]                   1
# CATERING EXPENSE [MUNOZ: SB23.362879]           1
# OFFICE EXPENSES                                 1
# EQUIPMENT PURCHASE [AMEX: SB23.362557]          1
# EVENT SERVICES & SUPPLIES                       1
# AIR TAVEL                                       1
# LOCK & KEY SERVICES                             1
# CPR TRAINING; CREDIT                            1
# SECURITY SERVICES [KELLER: SB23.6806]           1
# PHOTOGRAPHY/VIDEO PRODUCTION                    1
# MEETING EXPENSE: MEALS [AMEX: SB23.28895        1
# FIRE MARSHALL DETAIL                            1
# PERMIT                                          1
# PARKING SERVICES [BYERS: SB23.455479]           1
# AUDIO VISUAL SERVICES [AMEX: SB23.248392        1
# Name: expenditure_type, Length: 819, dtype: int64

# %%
df.loc[df['expenditure_type'].str.contains('Travel', case=False), 'expenditure_type'] = 'Travel'
df.loc[df['expenditure_type'].str.contains('Fee', case=False), 'expenditure_type'] = 'Misc Fees'
df.loc[df['expenditure_type'].str.contains('Rent', case=False), 'expenditure_type'] = 'Various Rentals'
df.loc[df['expenditure_type'].str.contains('Shipping', case=False), 'expenditure_type'] = 'Shipping'
df.loc[df['expenditure_type'].str.contains('Consult', case=False), 'expenditure_type'] = 'Various Consulting'
df.loc[df['expenditure_type'].str.contains('Payroll', case=False), 'expenditure_type'] = 'Payroll'
df.loc[df['expenditure_type'].str.contains('Phone', case=False), 'expenditure_type'] = 'Phone'
df.loc[df['expenditure_type'].str.contains('Event Supplies', case=False), 'expenditure_type'] = 'Event Supplies'
df.loc[df['expenditure_type'].str.contains('CATERING, FOOD & BEVERAGES', case=False), 'expenditure_type'] = 'Catering' 
df.loc[df['expenditure_type'].str.contains('OFFICE SUPPLIES', case=False), 'expenditure_type'] = 'Office Supplies'

# %%
df.to_csv('expenditures.csv')

# %%
expend = df
frames = [contr, expend]
concat_df = pd.concat(frames)

# %%
concat_df.head()
# Out:
#    Unnamed: 0          cand_nm  contb_receipt_amt contb_receipt_dt  \
# 0         0.0   Bernie Sanders             100.00       2016-02-28
# 1         1.0   Bernie Sanders              27.00       2016-04-05
# 2         2.0     Donald Trump              40.00       2016-07-01
# 3         3.0   Bernie Sanders               5.00       2016-04-25
# 4         4.0  Hillary Clinton              20.72       2016-10-07
#
#   contbr_city               contbr_employer              contbr_nm  \
# 0    BETHESDA                  NOT EMPLOYED          MICHIE, JAMES
# 1    AMESBURY  CATS N JAMMERS MUSIC STUDIOS           PEIRCE, ERIC
# 2  HARRISBURG                       RETIRED  HARGETT, JOYCE E MRS.
# 3      GOLDEN           THE CONFLICT CENTER           HICKS, MITZI
# 4  LONG BEACH       SUSAN WALSHE, LMFT, INC          WALSHE, SUSAN
#
#            contbr_occupation contbr_st  day  expenditure_amt expenditure_date  \
# 0               NOT EMPLOYED        MD   28              NaN              NaT
# 1                    TEACHER        MA    5              NaN              NaT
# 2                    RETIRED        OR    1              NaN              NaT
# 3    NONPROFIT ADMINISTRATOR        CO   25              NaN              NaT
# 4  MARRIAGE FAMILY THERAPIST        CA    7              NaN              NaT
#
#   expenditure_memo expenditure_type  month recipient_city recipient_nm  \
# 0              NaN              NaN      2            NaN          NaN
# 1              NaN              NaN      4            NaN          NaN
# 2              NaN              NaN      7            NaN          NaN
# 3              NaN              NaN      4            NaN          NaN
# 4              NaN              NaN     10            NaN          NaN
#
#   recipient_st transaction_type  year
# 0          NaN     Contribution  2016
# 1          NaN     Contribution  2016
# 2          NaN     Contribution  2016
# 3          NaN     Contribution  2016
# 4          NaN     Contribution  2016

# %%
#drops columns with unnecessary data
concat_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
concat_df.groupby(['cand_nm'])['contb_receipt_amt'].count().sort_values()
# Out:
# cand_nm
# Donald Trump       29385
# Bernie Sanders     76193
# Hillary Clinton    94422
# Name: contb_receipt_amt, dtype: int64

# %%
concat_df.to_csv('contrib_expendit.csv')

# %%
import pandas as pd 
df = pd.read_csv(('election_final.csv'), index_col=None)
#expenditures = pd.read_csv(('expenditures.csv'), index_col=None)

# %%
df
# Out:
#         Unnamed: 0          cand_nm              contbr_nm  \
# 0                0   Bernie Sanders          MICHIE, JAMES
# 1                1   Bernie Sanders           PEIRCE, ERIC
# 2                2     Donald Trump  HARGETT, JOYCE E MRS.
# 3                3   Bernie Sanders           HICKS, MITZI
# 4                4  Hillary Clinton          WALSHE, SUSAN
# 5                5  Hillary Clinton        KOSMOWSKI, ERIC
# 6                6  Hillary Clinton        THOMPSON, TRACY
# 7                7   Bernie Sanders          MICHAELS, DAN
# 8                8   Bernie Sanders         JAMES, BRANDON
# 9                9  Hillary Clinton     ROBINSON, LAWRENCE
# 10              10   Bernie Sanders         SIRIEIX, DAVID
# 11              11  Hillary Clinton      HAYNES, ELIZABETH
# 12              12     Donald Trump        TRIVITS, SHERYL
# 13              13  Hillary Clinton          MCKAY, SIDWAY
# 14              14   Bernie Sanders          POELKER, RYNE
# 15              15  Hillary Clinton             DUKE, JOAN
# 16              16  Hillary Clinton         ARZIO, JACKLYN
# 17              17   Bernie Sanders         PREVITI, CHRIS
# 18              18  Hillary Clinton        WILLAUER, CAROL
# 19              19   Bernie Sanders          LAITNER, JOHN
# 20              20   Bernie Sanders      YAMAMOTO, RICHARD
# 21              21   Bernie Sanders          MEYER, EILEEN
# 22              22   Bernie Sanders          JANISCH, ANNE
# 23              23   Bernie Sanders             NIX, CAROL
# 24              24     Donald Trump    FUECHTMANN, MICHAEL
# 25              25  Hillary Clinton             RAY, CATHY
# 26              26  Hillary Clinton            LEHR, KAREN
# 27              27     Donald Trump         WALRAVEN, DANA
# 28              28  Hillary Clinton     ACKAH-YENSU, DENIS
# 29              29   Bernie Sanders        SEBENIUS, CLARE
# ...            ...              ...                    ...
# 199970      199970   Bernie Sanders        AFZELIUS, JANET
# 199971      199971  Hillary Clinton          OVERETT, ADAM
# 199972      199972  Hillary Clinton           PAULIN, KATE
# 199973      199973   Bernie Sanders        TORRES, ORLANDO
# 199974      199974   Bernie Sanders          ALFORD, KYLIE
# 199975      199975   Bernie Sanders       BURROUGHS, KEITH
# 199976      199976  Hillary Clinton       MCGARRAH, ROBERT
# 199977      199977   Bernie Sanders           LEE, JANETTE
# 199978      199978  Hillary Clinton  MCGINLEY MYERS, NANCY
# 199979      199979     Donald Trump         ROBINSON, CARL
# 199980      199980     Donald Trump         WIEHE, EVERETT
# 199981      199981  Hillary Clinton      DUBOVSKY, ANTHONY
# 199982      199982   Bernie Sanders        PANTALE, JOANNE
# 199983      199983  Hillary Clinton         HELD, VIRGINIA
# 199984      199984  Hillary Clinton     SILVESTRI, STEPHEN
# 199985      199985  Hillary Clinton      MEYER-STROM, PAUL
# 199986      199986  Hillary Clinton       TIBBALS, CLINTON
# 199987      199987  Hillary Clinton       ISAACS, ARABELLA
# 199988      199988     Donald Trump   FARRIS, OWEETA W MS.
# 199989      199989   Bernie Sanders        APPLEGATE, JOEL
# 199990      199990  Hillary Clinton       SYNMOIE, PATRICK
# 199991      199991   Bernie Sanders       BERTA, ANASTASIA
# 199992      199992   Bernie Sanders          TAYLOR, GEOFF
# 199993      199993  Hillary Clinton          KINDER, JANET
# 199994      199994  Hillary Clinton     YOUNGWERTH, CHERYL
# 199995      199995  Hillary Clinton          EPSTEIN, JOSH
# 199996      199996   Bernie Sanders           ELLIS, JASON
# 199997      199997     Donald Trump         CONNER, STEVEN
# 199998      199998  Hillary Clinton        SELDNER, ELAINE
# 199999      199999  Hillary Clinton          DONAGHY, MARY
#
#                contbr_city contbr_st                         contbr_employer  \
# 0                 BETHESDA        MD                            NOT EMPLOYED
# 1                 AMESBURY        MA            CATS N JAMMERS MUSIC STUDIOS
# 2               HARRISBURG        OR                                 RETIRED
# 3                   GOLDEN        CO                     THE CONFLICT CENTER
# 4               LONG BEACH        CA                 SUSAN WALSHE, LMFT, INC
# 5               WASHINGTON        DC                          FRONTIERBRIDGE
# 6                 BERKELEY        CA      PALO ALTO FOUNDATION MEDICAL GROUP
# 7              SAINT CLOUD        MN              ST. CLOUD STATE UNIVERSITY
# 8              SPRINGFIELD        OH                           SELF-EMPLOYED
# 9                  MEMPHIS        TN                               WALGREENS
# 10                NEW YORK        NY                             741MPH INC.
# 11          UPPER MARLBORO        MD                           SELF-EMPLOYED
# 12             PARSONSBURG        MD                   INFORMATION REQUESTED
# 13                 BOULDER        CO                               CONCENTRA
# 14                 CHICAGO        IL                                    NONE
# 15               BALTIMORE        MD                                    HCIC
# 16            WALNUT CREEK        CA                                     CGI
# 17           PRIMOS SECANE        PA                                 RETIRED
# 18                PORTLAND        ME                                 RETIRED
# 19                  TUCSON        AZ                                    SELF
# 20                MILILANI        HI                            NOT EMPLOYED
# 21               BALTIMORE        MD  UNIVERSITY OF MARYLAND BALTIMORE COUNT
# 22              SAINT PAUL        MN                 UNIVERSITY OF MINNESOTA
# 23            INDEPENDENCE        WV                                    NONE
# 24                 ROSELLE        IL                                 RETIRED
# 25           SILVER SPRING        MD    PRINCE GEORGES COUNTY PUBLIC SCHOOLS
# 26              MORRISTOWN        NJ                      HIGH FOCUS CENTERS
# 27                ALVARADO        TX      COOK CHILDREN'S HEALTH CARE SYSTEM
# 28               CHARLOTTE        NC                   AXUM CAPITAL PARTNERS
# 29             LOS ANGELES        CA                                    SELF
# ...                    ...       ...                                     ...
# 199970         LAKE OSWEGO        OR                          INFINITY REHAB
# 199971            NEW YORK        NY                               LOGICPREP
# 199972            NEW YORK        NY                                    360I
# 199973              WESTON        FL                            NOT EMPLOYED
# 199974               ARDEN        NC                                   NCDOJ
# 199975         GULF SHORES        AL                                    NONE
# 199976            BETHESDA        MD                                 AFL-CIO
# 199977            FORT LEE        NJ             ADASIA COMMUNICATIONS, INC.
# 199978          SAINT PAUL        MN      UNIVERSITY OF ST. THOMAS MINNESOTA
# 199979            LORANGER        LA                              NON PROFIT
# 199980           LAFAYETTE        CO                   INFORMATION REQUESTED
# 199981            BERKELEY        CA      UNIVERSITY OF CALIFORNIA, BERKELEY
# 199982           MARCELLUS        MI                         BAND G DISCOUNT
# 199983            NEW YORK        NY                   INFORMATION REQUESTED
# 199984         MIAMI BEACH        FL                                   WANDA
# 199985            PORTLAND        OR                           NW PERMANENTE
# 199986           FREDERICK        CO                               U.S. NAVY
# 199987            BROOKLYN        NY                   INFORMATION REQUESTED
# 199988             MEMPHIS        TN                   INFORMATION REQUESTED
# 199989        SPANISH FORK        UT       PRUDENTIAL UTAH ELITE REAL ESTATE
# 199990            BROOKLYN        NY            NEW YORK CITY CLERK'S OFFICE
# 199991           SAN DIEGO        CA                                    SELF
# 199992         NORTHAMPTON        MA                            NOT EMPLOYED
# 199993           SUNNYVALE        CA               SUNNYVALE SCHOOL DISTRICT
# 199994          SCOTTSDALE        AZ                           SELF-EMPLOYED
# 199995            BROOKLYN        NY                        FIRST LOOK MEDIA
# 199996            GLENDALE        AZ                      SALT RIVER PROJECT
# 199997          GREENVILLE        OH                   INFORMATION REQUESTED
# 199998  MILLSTONE TOWNSHIP        NJ                                 RETIRED
# 199999            NEW YORK        NY                           SELF-EMPLOYED
#
#                   contbr_occupation  contb_receipt_amt contb_receipt_dt  \
# 0                      NOT EMPLOYED             100.00       2016-02-28
# 1                           TEACHER              27.00       2016-04-05
# 2                           RETIRED              40.00       2016-07-01
# 3           NONPROFIT ADMINISTRATOR               5.00       2016-04-25
# 4         MARRIAGE FAMILY THERAPIST              20.72       2016-10-07
# 5                          INVESTOR             250.00       2015-10-13
# 6                         PHYSICIAN              38.00       2016-01-12
# 7                      TECH SUPPORT               5.00       2016-05-28
# 8                            RETAIL              38.54       2015-09-05
# 9                        PHARMACIST              25.00       2016-02-04
# 10                      ADVERTISING               3.00       2016-04-02
# 11                     ORTHODONTIST              25.00       2016-10-10
# 12                     VETERINARIAN              60.00       2016-08-09
# 13               PHYSICAL THERAPIST             100.00       2015-11-09
# 14                     NOT EMPLOYED              15.00       2016-03-16
# 15            MANAGEMENT CONSULTANT              25.00       2016-10-24
# 16           SENIOR VP, REAL ESTATE              10.00       2016-02-05
# 17                          RETIRED              15.00       2016-05-31
# 18                          MANAGER              25.00       2016-09-29
# 19                        ECONOMIST              50.00       2016-02-24
# 20                          RETIRED              35.00       2016-02-12
# 21              ASSISTANT PROFESSOR              27.00       2016-04-14
# 22      CLINICAL RESEARCH ASSOCIATE              25.00       2016-01-31
# 23                     NOT EMPLOYED              35.00       2016-02-22
# 24                          RETIRED              20.00       2016-06-25
# 25                          TEACHER              25.00       2016-06-07
# 26                          RN, LSW               5.00       2016-10-21
# 27                          MANAGER              83.59       2016-09-10
# 28                   PRIVATE EQUITY             250.00       2016-09-30
# 29                CREATIVE DIRECTOR             100.00       2016-04-06
# ...                             ...                ...              ...
# 199970                          SLP               1.66       2016-04-15
# 199971                        TUTOR              25.00       2016-09-30
# 199972                  ADVERTISING             100.00       2016-10-02
# 199973                 NOT EMPLOYED              35.00       2016-02-22
# 199974           FORENSIC SCIENTIST              27.00       2016-04-03
# 199975                 NOT EMPLOYED               5.00       2015-12-30
# 199976                     ATTORNEY              50.00       2016-02-20
# 199977                   COPYWRITER              15.00       2016-02-27
# 199978       INSTRUCTIONAL DESIGNER              25.00       2016-09-26
# 199979              BUSINESS MANGER              28.00       2016-06-21
# 199980        INFORMATION REQUESTED             400.00       2016-10-21
# 199981                      PAINTER              15.00       2016-11-05
# 199982              SALES ASSOCIATE              54.00       2016-04-11
# 199983        INFORMATION REQUESTED             150.00       2016-04-26
# 199984            CREATIVE DIRECTOR              25.00       2016-11-03
# 199985                 PSYCHIATRIST              10.00       2016-08-15
# 199986                      RETIRED              25.00       2016-05-21
# 199987        INFORMATION REQUESTED              50.00       2016-06-16
# 199988        INFORMATION REQUESTED              16.00       2016-07-06
# 199989                      REALTOR              11.00       2016-05-18
# 199990                     ATTORNEY              25.00       2015-10-23
# 199991                     DESIGNER             100.00       2016-01-18
# 199992                 NOT EMPLOYED             108.00       2015-11-15
# 199993    SPECIAL EDUCATION TEACHER             100.00       2016-10-18
# 199994                     DESIGNER              50.00       2016-09-29
# 199995                        MEDIA             200.00       2016-10-20
# 199996             COMPUTER ANALYST              22.00       2016-03-31
# 199997        INFORMATION REQUESTED               4.00       2016-08-05
# 199998                      TEACHER               1.00       2015-10-15
# 199999      VIDEO PRODUCTION/ACTING               5.00       2016-06-07
#
#         month  day  year
# 0           2   28  2016
# 1           4    5  2016
# 2           7    1  2016
# 3           4   25  2016
# 4          10    7  2016
# 5          10   13  2015
# 6           1   12  2016
# 7           5   28  2016
# 8           9    5  2015
# 9           2    4  2016
# 10          4    2  2016
# 11         10   10  2016
# 12          8    9  2016
# 13         11    9  2015
# 14          3   16  2016
# 15         10   24  2016
# 16          2    5  2016
# 17          5   31  2016
# 18          9   29  2016
# 19          2   24  2016
# 20          2   12  2016
# 21          4   14  2016
# 22          1   31  2016
# 23          2   22  2016
# 24          6   25  2016
# 25          6    7  2016
# 26         10   21  2016
# 27          9   10  2016
# 28          9   30  2016
# 29          4    6  2016
# ...       ...  ...   ...
# 199970      4   15  2016
# 199971      9   30  2016
# 199972     10    2  2016
# 199973      2   22  2016
# 199974      4    3  2016
# 199975     12   30  2015
# 199976      2   20  2016
# 199977      2   27  2016
# 199978      9   26  2016
# 199979      6   21  2016
# 199980     10   21  2016
# 199981     11    5  2016
# 199982      4   11  2016
# 199983      4   26  2016
# 199984     11    3  2016
# 199985      8   15  2016
# 199986      5   21  2016
# 199987      6   16  2016
# 199988      7    6  2016
# 199989      5   18  2016
# 199990     10   23  2015
# 199991      1   18  2016
# 199992     11   15  2015
# 199993     10   18  2016
# 199994      9   29  2016
# 199995     10   20  2016
# 199996      3   31  2016
# 199997      8    5  2016
# 199998     10   15  2015
# 199999      6    7  2016
#
# [200000 rows x 12 columns]

# %%
expenditures.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df = df.rename(columns={'contb_receipt_amt': 'contribution_amt', 'contb_receipt_dt': 'contribution_date'})

# %%
df['contbr_st'].unique()
# Out:
# array(['MD', 'MA', 'OR', 'CO', 'CA', 'DC', 'MN', 'OH', 'TN', 'NY', 'IL',
#        'PA', 'ME', 'AZ', 'HI', 'WV', 'NJ', 'TX', 'NC', 'WA', 'FL', 'NH',
#        'VA', 'MO', 'MS', 'GA', 'KS', 'IN', 'KY', 'CT', 'VT', 'UT', 'IA',
#        'MI', 'RI', 'AK', 'WI', 'ND', 'NE', 'LA', 'OK', 'NV', 'WY', 'AL',
#        'NM', 'ZZ', 'SC', 'SD', 'DE', 'MT', 'AR', 'PR', 'ON', 'ID', 'VI',
#        'AE', 'AS', 'AP', 'AA', 'GU', 'BC', 'ST', 'BR', 'MP', 'CH', 'NS',
#        'QC', 'AB'], dtype=object)

# %%
df['contbr_st'] = df['contbr_st'].replace(['LA'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['BC'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['ZZ'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['PR'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['XX'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['AP'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['AE'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['AA'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['MP'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['VI'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['ON'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['GU'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['NS'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['AU'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['AS'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['IS'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['QC'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['SO'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['FF'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['AB'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['CH'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['ST'], 'OTHER')
df['contbr_st'] = df['contbr_st'].replace(['BR'], 'OTHER')

# %%
df['contbr_st'].nunique()
# Out:
# 51

# %%
expenditures['recipient_st'].nunique()
# Out:
# 60

# %%
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['KA'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['LA'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['MP'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['NB'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['ON'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['PR'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['SA'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['UK'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['VI'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['AB'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['AM'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['BC'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['ZZ'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['AU'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['GB'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['GU'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['QC'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['D.'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['LO'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['AS'], 'OTHER')
expenditures['recipient_st'] = expenditures['recipient_st'].replace(['FF'], 'OTHER')

# %%
expenditures['recipient_st'].nunique()
# Out:
# 51

# %%
df['contbr_occupation'] = df['contbr_occupation'].replace(['INFORMATION REQUESTED PER BEST EFFORTS'], 'UNKNOWN')
df['contbr_occupation'] = df['contbr_occupation'].replace(['INFORMATION REQUESTED'], 'UNKNOWN')
df['contbr_occupation'] = df['contbr_occupation'].replace(['RN'], 'REGISTERED NURSE')
df['contbr_occupation'] = df['contbr_occupation'].replace(['EDUCATOR'], 'TEACHER')

# %%
df.loc[df['contbr_occupation'].str.contains('Not Employed', case=False), 'contbr_occupation'] = 'Unemployed'
df.loc[df['contbr_occupation'].str.contains('Retired', case=False), 'contbr_occupation'] = 'Retired'
df.loc[df['contbr_occupation'].str.contains('Unknown', case=False), 'contbr_occupation'] = 'Unknown'
df.loc[df['contbr_occupation'].str.contains('Attorney', case=False), 'contbr_occupation'] = 'Attorney'
df.loc[df['contbr_occupation'].str.contains('teacher', case=False), 'contbr_occupation'] = 'Teacher'
df.loc[df['contbr_occupation'].str.contains('Professor', case=False), 'contbr_occupation'] = 'Professor'
df.loc[df['contbr_occupation'].str.contains('PHYSICIAN', case=False), 'contbr_occupation'] = 'Physician'
df.loc[df['contbr_occupation'].str.contains('Consultant', case=False), 'contbr_occupation'] = 'Consultant'
df.loc[df['contbr_occupation'].str.contains('NURSE', case=False), 'contbr_occupation'] = 'RN' 
df.loc[df['contbr_occupation'].str.contains('ENGINEER', case=False), 'contbr_occupation'] = 'Engineer'

# %%
df['contbr_occupation'].value_counts()
# Out:
# Unemployed                            21498
# Retired                               16199
# Unknown                                9101
# Teacher                                7682
# Attorney                               7412
# Engineer                               6288
# Professor                              5667
# Consultant                             5333
# Physician                              4242
# RN                                     3920
# LAWYER                                 1991
# SALES                                  1843
# MANAGER                                1764
# WRITER                                 1623
# ARTIST                                 1206
# SELF EMPLOYED                           999
# CEO                                     993
# PSYCHOLOGIST                            985
# OWNER                                   950
# STUDENT                                 891
# ACCOUNTANT                              861
# BUSINESS OWNER                          844
# SOCIAL WORKER                           838
# REALTOR                                 834
# PRESIDENT                               748
# MARKETING                               723
# PROJECT MANAGER                         710
# EXECUTIVE                               686
# HOMEMAKER                               674
# DIRECTOR                                666
#                                       ...
# PAYCHOLOGIST                              1
# DEPUTY EDITOR                             1
# PHOTO ANALYST                             1
# WIFE                                      1
# MARKETING SYSTEMS SPECIALIST              1
# OPERATING ROOM ASSISTANT                  1
# DIRECTOR OF EDUCATIONAL TECHNOLOGY        1
# AVIATION MAINTENANCE                      1
# PART TIME RECEPTIONIST                    1
# PT PROP MGR                               1
# SENIOR ASSOCIATE DIRECTOR                 1
# AUTO SALES.                               1
# COMMUNITY COLLEGE PRESIDENT               1
# SUPERINTENDENT OF PUBLIC WORKS            1
# EMMANUEL COLLEGE                          1
# VETERAN ADVOCATE                          1
# NERIUM BRAND PARTNER                      1
# CHILD CARE CENTER DIRECTOR                1
# COUNTY VETERANS SERVICES OFFICER          1
# SYSTEMS ADMIN / OPERATIONS                1
# TUTOR AND MUSICIAN                        1
# ASSOCIATE STUDIO MANAGER                  1
# SR NOC TECHNICIAN                         1
# GLOBAL PRODUCT MANAGER                    1
# RETAILOR                                  1
# TECHNICAL MARKETING                       1
# SPECIAL ED. BEHAVIOR TECH                 1
# COMMUNITY PARKS TEAM MEMBER               1
# SOFTWARE INFRASTRUCTURE ARCHITECT         1
# INTERNET BUSINESS OWNER                   1
# Name: contbr_occupation, Length: 20628, dtype: int64

# %%
expenditures['cand_nm'].unique()
# Out:
# array(['Hillary Clinton', 'Bernie Sanders', 'Donald Trump'], dtype=object)

# %%
df.to_csv('full_contributions.csv')
expenditures.to_csv('full_expenditures.csv')

# %%
import pandas as pd
df = pd.read_csv('full_contributions.csv')

# %%
df['month'].value_counts()
# Out:
# 10    26809
# 3     22316
# 7     21848
# 4     20429
# 9     19105
# 8     17896
# 5     16063
# 6     15970
# 2     14174
# 11    13996
# 1      6575
# 12     4819
# Name: month, dtype: int64

# %% [markdown]
# REFERENCES
# > https://stackoverflow.com/questions/20297317/python-dataframe-pandas-drop-column-using-int
# > https://stackoverflow.com/questions/21902080/python-pandas-not-reading-first-column-from-csv-file
# > https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
# > https://chrisalbon.com/python/data_wrangling/pandas_saving_dataframe_as_csv/
# > https://stackoverflow.com/questions/27060098/replacing-few-values-in-a-pandas-dataframe-column-with-another-value
# > https://stackoverflow.com/questions/11346283/renaming-columns-in-pandas
# > https://stackoverflow.com/questions/44068913/python-pandas-seed-for-random-generator
# > https://stackoverflow.com/questions/38085547/random-sample-of-a-subset-of-a-dataframe-in-pandas
# > https://stackoverflow.com/questions/12555323/adding-new-column-to-existing-dataframe-in-python-pandas
# > https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html
# > https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html
# > https://stackoverflow.com/questions/34913546/remove-low-counts-from-pandas-data-frame-column-on-condition
# > https://stackoverflow.com/questions/35678083/pandas-delete-rows-of-a-dataframe-if-total-count-of-a-particular-column-occurs
# > https://erikrood.com/Python_References/rows_cols_python.html
# > https://datascience.stackexchange.com/questions/12645/how-to-count-the-number-of-missing-values-in-each-row-in-pandas-dataframe
# >https://stackoverflow.com/questions/13413590/how-to-drop-rows-of-pandas-dataframe-whose-value-in-certain-columns-is-nan
